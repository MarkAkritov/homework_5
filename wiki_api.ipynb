# %%
import utils
import wikipedia
import matplotlib.pyplot as plt

# %%
page_wiki = wikipedia.page("Society")

# %%
page = utils.request_url(page_wiki.url)
base_url = "https://en.wikipedia.org/"

# %%
scrape_all = utils.Scrape_All(page_wiki.html(), base_url)

# %%
scrape_all.get_links()
# Out:
# ['/wiki/Society_(disambiguation)',
#  '/wiki/Anthropology',
#  '/wiki/Outline_of_anthropology',
#  '/wiki/History_of_anthropology',
#  '/wiki/Archaeology',
#  '/wiki/Biological_anthropology',
#  '/wiki/Cultural_anthropology',
#  '/wiki/Linguistic_anthropology',
#  '/wiki/Social_anthropology',
#  '/wiki/Archaeology',
#  '/wiki/Aerial_archaeology',
#  '/wiki/Aviation_archaeology',
#  '/wiki/Battlefield_archaeology',
#  '/wiki/Biblical_archaeology',
#  '/wiki/Bioarchaeology',
#  '/wiki/Environmental_archaeology',
#  '/wiki/Ethnoarchaeology',
#  '/wiki/Feminist_archaeology',
#  '/wiki/Forensic_anthropology',
#  '/wiki/Maritime_archaeology',
#  '/wiki/Paleoethnobotany',
#  '/wiki/Zooarchaeology',
#  '/wiki/Biological_anthropology',
#  '/wiki/Anthrozoology',
#  '/wiki/Biocultural_anthropology',
#  '/wiki/Evolutionary_anthropology',
#  '/wiki/Forensic_anthropology',
#  '/wiki/Molecular_anthropology',
#  '/wiki/Neuroanthropology',
#  '/wiki/Nutritional_anthropology',
# ...

# %%
head_par = scrape_all.get_head_par()

# %%
scrape_all.get_user_lists()
# Out:
# []

# %%
cleaner = utils.Cleaner(str(head_par))

# %%
cleaner = utils.Super_List(cleaner.lowercase()).merge()

# %%
utils.Cleaner(cleaner).freq_dist()
